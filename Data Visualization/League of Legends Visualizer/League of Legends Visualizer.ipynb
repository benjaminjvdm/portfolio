# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lol = pd.read_csv('League of Legends Champion Stats 12.11.csv', header=0 )
lol.head()
# Out:
#      Name     Class Role Tier  Score  Trend   Win %  Role % Pick %   Ban %  \
# 0  Aatrox   Fighter  TOP  God  69.36   3.20  48.94%  92.64%  7.31%   5.43%
# 1    Ahri      Mage  MID  God  73.72  -5.74  50.04%  95.11%  9.83%   8.59%
# 2   Akali  Assassin  MID    S  58.67   2.63  48.70%  68.12%  6.26%  11.79%
# 3   Akali  Assassin  TOP    B  43.83  -0.89  47.58%  30.92%  2.67%  11.79%
# 4  Akshan  Marksman  MID    B  46.91  -0.64  49.50%  58.88%  2.93%   7.60%
#
#     KDA
# 0  1.96
# 1  2.63
# 2  2.39
# 3  2.05
# 4  2.22

# %%
lol["Win %"] = lol["Win %"].str[:-1]
lol["Role %"] = lol["Role %"].str[:-1]
lol["Pick %"] = lol["Pick %"].str[:-1]
lol["Ban %"] = lol["Ban %"].str[:-1]
lol[['Win %','Role %', 'Pick %', 'Ban %']] = lol[['Win %','Role %', 'Pick %', 'Ban %']].apply(pd.to_numeric)
lol.sort_values(by='Ban %')
# Out:
#          Name     Class     Role Tier  Score  Trend  Win %  Role %  Pick %  \
# 148      Ryze      Mage      MID    D  36.42   9.02  46.06   79.84    1.96
# 149      Ryze      Mage      TOP    D  22.99   1.65  44.52   16.59    0.41
# 106    Maokai      Tank  SUPPORT    C  37.94  -3.47  49.05   70.95    1.22
# 107    Maokai      Tank      TOP    D  28.33  -4.73  46.36   22.21    0.41
# 167   Skarner   Fighter   JUNGLE    A  51.24  12.92  52.39   75.95    0.84
# ..        ...       ...      ...  ...    ...    ...    ...     ...     ...
# 217    Wukong   Fighter   JUNGLE    S  64.88 -26.51  52.94   76.81    8.18
# 229     Yuumi   Support  SUPPORT  God  94.89  18.06  50.58   98.46   13.33
# 232       Zed  Assassin      MID  God  67.98  -3.42  48.20   73.40    7.34
# 233       Zed  Assassin   JUNGLE    B  42.46   0.90  47.03   21.98    2.01
# 19   Bel'Veth   Fighter   JUNGLE  God  94.93   0.00  52.85   89.76   19.56
#
#      Ban %   KDA
# 148   0.13  2.16
# 149   0.14  1.79
# 106   0.15  2.17
# 107   0.15  2.05
# 167   0.19  3.05
# ..     ...   ...
# 217  25.59  2.93
# 229  28.71  4.37
# 232  28.72  2.34
# 233  28.72  2.58
# 19   48.20  2.38
#
# [241 rows x 11 columns]

# %%
lol_ADC = lol.loc[lol['Role'] == 'ADC'].reset_index()
lol_JG = lol.loc[lol['Role'] == 'JUNGLE'].reset_index()
lol_MID = lol.loc[lol['Role'] == 'MID'].reset_index()
lol_SUP = lol.loc[lol['Role'] == 'SUPPORT'].reset_index()
lol_TOP = lol.loc[lol['Role'] == 'TOP'].reset_index()

# %%
count_role = lol.groupby('Role').Name.count().reset_index()
count_role

palette_color = sns.color_palette('bright')
plt.pie(count_role.Name, labels = count_role.Role,autopct='%.2f')
plt.title('Percent of each role in League of Legends')
plt.show()
